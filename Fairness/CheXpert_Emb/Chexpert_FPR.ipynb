# %%
import pandas as pd
import numpy as np
import math
import random as python_random
import io
import os
import glob
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from IPython.display import clear_output

seeds=[19,31,38,47,77]

# %%
diseases = ['No Finding']

diseases_abbr = {'No Finding': 'No Finding'}

age_decile = ['60-80', '40-60', '20-40', '80+', '0-20']

gender = ['M', 'F']

race = ['WHITE', 'BLACK/AFRICAN AMERICAN',
        'HISPANIC/LATINO', 'OTHER', 'ASIAN',
        'AMERICAN INDIAN/ALASKA NATIVE']

factor = [gender, age_decile, race]

factor_str = ['gender', 'age_decile', 'race']

# %%
###  FPR
def fpr(df, d, c, category_name):
    pred_disease = "bi_" + d
    gt = df.loc[(df[d] == 0) & (df[category_name] == c), :]
    pred = df.loc[(df[pred_disease] == 1) & (df[d] == 0) & (df[category_name] == c), :]
    if len(gt) != 0:
        FPR = len(pred) / len(gt)
        return FPR
    else:
        # print("Disease", d, "in category", c, "has zero division error")
        return -1

# %%
def FP_FN_NF_CheXpert(df, diseases, category, category_name,seed=19,fpr_npr_path="default"):

  #return FPR and FNR per subgroup and the unber of patients with 0 No-finding in test set.
  FP_total = []
  percentage_total = []
  FN_total = []


  if category_name == 'race':
    FPR_race = pd.DataFrame(diseases, columns=["diseases"])

  if category_name == 'gender':
    FPR_sex = pd.DataFrame(diseases, columns=["diseases"])

  if category_name == 'age_decile':
    FPR_age = pd.DataFrame(diseases, columns=["diseases"])

  print("FP in CheXpert====================================")

  for c in category:
    FP_y = []
    FN_y = []
    percentage_y = []

    for d in diseases:
      pred_disease = "bi_" + d
      gt_fp = df.loc[(df[d] == 0) & (df[category_name] == c), :]
      gt_fn = df.loc[(df[d] == 1) & (df[category_name] == c), :]
      pred_fp = df.loc[(df[pred_disease] == 1) & (df[d] == 0) & (df[category_name] == c), :]
      pred_fn = df.loc[(df[pred_disease] == 0) & (df[d] == 1) & (df[category_name] == c), :]

      #number of patient in subgroup with actual NF=0
      pi_gy = df.loc[(df[d] == 0) & (df[category_name] == c), :]

      if len(gt_fp) != 0 :

        FPR = len(pred_fp) / len(gt_fp)
        Percentage = len(pi_gy)
        FP_y.append(round(FPR,3))
        percentage_y.append(round(Percentage,3))
        # print(c)
        print(len(pred_fp),'--' ,len(gt_fp),'====',c)
        # print("FPR in " + category[c]  + " for " + diseases[d] + " is: " + str(FPR))

      else:

        FP_y.append(np.NaN)
        percentage_y.append(0)

      if len(gt_fn) != 0 :
        FNR = len(pred_fn) / len(gt_fn)
        FN_y.append(round(FNR,3))


      else:
        FN_y.append(np.NaN)

      FP_total.append(FP_y)
      percentage_total.append(percentage_y)
      FN_total.append(FN_y)

    # print("False Positive Rate in " + category[c] + " for " + diseases[d] + " is: " + str(FPR))

  for  i in range(len(FN_total)):

    if category_name == 'gender':
      if i == 0:
        Perc_S = pd.DataFrame(percentage_total[i], columns=["#M"])
        FPR_sex = pd.concat([FPR_sex, Perc_S.reindex(FPR_sex.index)], axis=1)

        FPR_S = pd.DataFrame(FP_total[i], columns=["FPR_M"])
        FPR_sex = pd.concat([FPR_sex, FPR_S.reindex(FPR_sex.index)], axis=1)
        FNR_S = pd.DataFrame(FN_total[i], columns=["FNR_M"])
        FPR_sex = pd.concat([FPR_sex, FNR_S.reindex(FPR_sex.index)], axis=1)

      if i == 1:
        Perc_S = pd.DataFrame(percentage_total[i], columns=["#F"])
        FPR_sex = pd.concat([FPR_sex, Perc_S.reindex(FPR_sex.index)], axis=1)

        FPR_S = pd.DataFrame(FP_total[i], columns=["FPR_F"])
        FPR_sex = pd.concat([FPR_sex, FPR_S.reindex(FPR_sex.index)], axis=1)

        FNR_S = pd.DataFrame(FN_total[i], columns=["FNR_F"])
        FPR_sex = pd.concat([FPR_sex, FNR_S.reindex(FPR_sex.index)], axis=1)
        FPR_sex.to_csv(fpr_npr_path+"run_"+str(seed)+"FPR_FNR_NF_sex.csv")

    if category_name == 'age_decile':

      if i == 0:
        Perc_A = pd.DataFrame(percentage_total[i], columns=["#60-80"])
        FPR_age = pd.concat([FPR_age, Perc_A.reindex(FPR_age.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_60-80"])
        FPR_age = pd.concat([FPR_age, FPR_A.reindex(FPR_age.index)], axis=1)

        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_60-80"])
        FPR_age = pd.concat([FPR_age, FNR_A.reindex(FPR_age.index)], axis=1)

      if i == 1:

        Perc_A = pd.DataFrame(percentage_total[i], columns=["#40-60"])
        FPR_age = pd.concat([FPR_age, Perc_A.reindex(FPR_age.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_40-60"])
        FPR_age = pd.concat([FPR_age, FPR_A.reindex(FPR_age.index)], axis=1)

        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_40-60"])
        FPR_age = pd.concat([FPR_age, FNR_A.reindex(FPR_age.index)], axis=1)

      if i == 2:

        Perc_A = pd.DataFrame(percentage_total[i], columns=["#20-40"])
        FPR_age = pd.concat([FPR_age, Perc_A.reindex(FPR_age.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_20-40"])
        FPR_age = pd.concat([FPR_age, FPR_A.reindex(FPR_age.index)], axis=1)
        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_20-40"])
        FPR_age = pd.concat([FPR_age, FNR_A.reindex(FPR_age.index)], axis=1)

      if i == 3:
        Perc_A = pd.DataFrame(percentage_total[i], columns=["#80+"])
        FPR_age = pd.concat([FPR_age, Perc_A.reindex(FPR_age.index)], axis=1)
        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_80+"])
        FPR_age = pd.concat([FPR_age, FPR_A.reindex(FPR_age.index)], axis=1)
        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_80+"])
        FPR_age = pd.concat([FPR_age, FNR_A.reindex(FPR_age.index)], axis=1)

      if i == 4:

        Perc_A = pd.DataFrame(percentage_total[i], columns=["#0-20"])
        FPR_age = pd.concat([FPR_age, Perc_A.reindex(FPR_age.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_0-20"])
        FPR_age = pd.concat([FPR_age, FPR_A.reindex(FPR_age.index)], axis=1)

        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_0-20"])
        FPR_age = pd.concat([FPR_age, FNR_A.reindex(FPR_age.index)], axis=1)
        FPR_age.to_csv(fpr_npr_path+"run_"+str(seed)+"FPR_FNR_NF_age.csv")

    if category_name == 'race':

      if i == 0:

        Perc_A = pd.DataFrame(percentage_total[i], columns=["#White"])
        FPR_race = pd.concat([FPR_race, Perc_A.reindex(FPR_race.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_White"])
        FPR_race = pd.concat([FPR_race, FPR_A.reindex(FPR_race.index)], axis=1)

        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_White"])
        FPR_race = pd.concat([FPR_race, FNR_A.reindex(FPR_race.index)], axis=1)


      if i == 1:
        Perc_A = pd.DataFrame(percentage_total[i], columns=["#Black"])
        FPR_race = pd.concat([FPR_race, Perc_A.reindex(FPR_race.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_Black"])
        FPR_race = pd.concat([FPR_race, FPR_A.reindex(FPR_race.index)], axis=1)

        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_Black"])
        FPR_race = pd.concat([FPR_race, FNR_A.reindex(FPR_race.index)], axis=1)


      if i == 2:
        Perc_A = pd.DataFrame(percentage_total[i], columns=["#Hisp"])
        FPR_race = pd.concat([FPR_race, Perc_A.reindex(FPR_race.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_Hisp"])
        FPR_race = pd.concat([FPR_race, FPR_A.reindex(FPR_race.index)], axis=1)

        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_Hisp"])
        FPR_race = pd.concat([FPR_race, FNR_A.reindex(FPR_race.index)], axis=1)

      if i == 3:
        Perc_A = pd.DataFrame(percentage_total[i], columns=["#Other"])
        FPR_race = pd.concat([FPR_race, Perc_A.reindex(FPR_race.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_Other"])
        FPR_race = pd.concat([FPR_race, FPR_A.reindex(FPR_race.index)], axis=1)

        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_Other"])
        FPR_race = pd.concat([FPR_race, FNR_A.reindex(FPR_race.index)], axis=1)


      if i == 4:
        Perc_A = pd.DataFrame(percentage_total[i], columns=["#Asian"])
        FPR_race = pd.concat([FPR_race, Perc_A.reindex(FPR_race.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_Asian"])
        FPR_race = pd.concat([FPR_race, FPR_A.reindex(FPR_race.index)], axis=1)

        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_Asian"])
        FPR_race = pd.concat([FPR_race, FNR_A.reindex(FPR_race.index)], axis=1)

      if i == 5:
        Perc_A = pd.DataFrame(percentage_total[i], columns=["#American"])
        FPR_race = pd.concat([FPR_race, Perc_A.reindex(FPR_race.index)], axis=1)

        FPR_A = pd.DataFrame(FP_total[i], columns=["FPR_American"])
        FPR_race = pd.concat([FPR_race, FPR_A.reindex(FPR_race.index)], axis=1)

        FNR_A = pd.DataFrame(FN_total[i], columns=["FNR_American"])
        FPR_race = pd.concat([FPR_race, FNR_A.reindex(FPR_race.index)], axis=1)
        FPR_race.to_csv(fpr_npr_path+"run_"+str(seed)+"FPR_FNR_NF_race.csv")

# %%
def FP_NF_CheXpert_Inter(df, diseases, category1, category_name1,category2,category_name2,seed=19,fpr_npr_path_2_group_intersection="default"):

  if (category_name1 == 'gender')  &  (category_name2 == 'race'):
    FP_RaceSex = pd.DataFrame(category2, columns=["race"])

  if (category_name1 == 'gender')  &  (category_name2 == 'age_decile'):
    FP_AgeSex = pd.DataFrame(category2, columns=["Age"])


  if (category_name1 == 'race')  &  (category_name2 == 'age_decile'):
    FP_RaceAge = pd.DataFrame(category2, columns=["age"])

  print("==================================== Calculating FP in vector embedded CXP====================================")

  i = 0

  for c1 in range(len(category1)):
    FPR_list = []
    FNR_list = []

    for c2 in range(len(category2)):

      for d in range(len(diseases)):

        pred_disease = "bi_" + diseases[d]
        gt_fp =   df.loc[((df[diseases[d]] == 0)  & (df[category_name1] == category1[c1]) &
         (df[category_name2] == category2[c2])), :]

        gt_fn =   df.loc[((df[diseases[d]] == 1)  & (df[category_name1] == category1[c1]) &
         (df[category_name2] == category2[c2])), :]

        pred_fp = df.loc[((df[pred_disease] == 1) & (df[diseases[d]] == 0) & (df[category_name1] == category1[c1]) &
                          (df[category_name2] == category2[c2])), :]
        pred_fn = df.loc[((df[pred_disease] == 0) & (df[diseases[d]] == 1) & (df[category_name1] == category1[c1]) &
                          (df[category_name2] == category2[c2])), :]

        if len(gt_fp) != 0:
          FPR = len(pred_fp) / len(gt_fp)
          print(len(pred_fp),'--' ,len(gt_fp))
          print("False Positive Rate in " + category1[c1] +"/" + category2[c2] + " for " + diseases[d] + " is: " + str(FPR))

        else:
          FPR = np.NaN
          print("False Positive Rate in " + category1[c1] +"/" + category2[c2] + " for " + diseases[d] + " is: N\A")

        print('=======================================================================================================')

      FPR_list.append(round(FPR,3))


    if (category_name1 == 'gender')  &  (category_name2 == 'age_decile'):

      if i == 0:
        FPR_SA = pd.DataFrame(FPR_list, columns=["FPR_M"])
        FP_AgeSex = pd.concat([FP_AgeSex, FPR_SA.reindex(FP_AgeSex.index)], axis=1)

      if i == 1:
        FPR_SA = pd.DataFrame(FPR_list, columns=["FPR_F"])
        FP_AgeSex = pd.concat([FP_AgeSex, FPR_SA.reindex(FP_AgeSex.index)], axis=1)

    if (category_name1 == 'gender')  &  (category_name2 == 'race'):

      if i == 0:
        FPR_SR = pd.DataFrame(FPR_list, columns=["FPR_M"])
        FP_RaceSex = pd.concat([FP_RaceSex, FPR_SR.reindex(FP_RaceSex.index)], axis=1)

      if i == 1:
        FPR_SR = pd.DataFrame(FPR_list, columns=["FPR_F"])
        FP_RaceSex = pd.concat([FP_RaceSex, FPR_SR.reindex(FP_RaceSex.index)], axis=1)

    if (category_name1 == 'race')  &  (category_name2 == 'age_decile'):

      if i == 0:

        FPR_RIn = pd.DataFrame(FPR_list, columns=["FPR_White"])
        FP_RaceAge = pd.concat([FP_RaceAge, FPR_RIn.reindex(FP_RaceAge.index)], axis=1)

      if i == 1:
        FPR_RIn = pd.DataFrame(FPR_list, columns=["FPR_Black"])
        FP_RaceAge = pd.concat([FP_RaceAge, FPR_RIn.reindex(FP_RaceAge.index)], axis=1)

      if i == 2:

        FPR_RIn = pd.DataFrame(FPR_list, columns=["FPR_Hisp"])
        FP_RaceAge = pd.concat([FP_RaceAge, FPR_RIn.reindex(FP_RaceAge.index)], axis=1)

      if i == 3:
        FPR_RIn = pd.DataFrame(FPR_list, columns=["FPR_Other"])
        FP_RaceAge = pd.concat([FP_RaceAge, FPR_RIn.reindex(FP_RaceAge.index)], axis=1)

      if i == 4:
        FPR_RIn = pd.DataFrame(FPR_list, columns=["FPR_Asian"])
        FP_RaceAge = pd.concat([FP_RaceAge, FPR_RIn.reindex(FP_RaceAge.index)], axis=1)

      if i == 5:

        FPR_RIn = pd.DataFrame(FPR_list, columns=["FPR_American"])
        FP_RaceAge = pd.concat([FP_RaceAge, FPR_RIn.reindex(FP_RaceAge.index)], axis=1)

    i += 1


  if (category_name1 == 'gender')  &  (category_name2 == 'race'):
    FP_RaceSex.to_csv(fpr_npr_path_2_group_intersection+"run_"+str(seed)+"FP_RaceSex.csv")

  if (category_name1 == 'race')  &  (category_name2 == 'age_decile'):
    FP_RaceAge.to_csv(fpr_npr_path_2_group_intersection+"run_"+str(seed)+"FP_RaceAge.csv")

  if (category_name1 == 'gender')  &  (category_name2 == 'age_decile'):
    FP_AgeSex.to_csv(fpr_npr_path_2_group_intersection+"run_"+str(seed)+"FP_AgeSex.csv")

# %%
def FP_NF_CheXpert_threegroup_Inter(df, diseases, category1, category_name1,category2,
                      category_name2,category3,category_name3,seed=19,fpr_npr_path_3_group_intersection="default"):


  if (category_name1 == 'gender')  &  (category_name2 == 'age_decile') & (category_name3 == 'race'):
    FP_RaceAgeSex = pd.DataFrame(category3, columns=["race"])

  print("==================================== Calculating FP in vector embedded mimic cxr====================================")

  i = 0

  for c1 in range(len(category1)):

    # FPR_list = []

    for c2 in range(len(category2)):
      FPR_list = []


      for c3 in range(len(category3)):

        for d in range(len(diseases)):

          pred_disease = "bi_" + diseases[d]
          gt_fp =   df.loc[((df[diseases[d]] == 0)  & (df[category_name1] == category1[c1]) &
           (df[category_name2] == category2[c2]) & (df[category_name3] == category3[c3])), :]

          gt_fn =   df.loc[((df[diseases[d]] == 1)  & (df[category_name1] == category1[c1]) &
            (df[category_name2] == category2[c2]) & (df[category_name3] == category3[c3])), :]

          pred_fp = df.loc[((df[pred_disease] == 1) & (df[diseases[d]] == 0) & (df[category_name1] == category1[c1]) &
             (df[category_name2] == category2[c2]) & (df[category_name3] == category3[c3])), :]

          pred_fn = df.loc[((df[pred_disease] == 0) & (df[diseases[d]] == 1) & (df[category_name1] == category1[c1]) &
                          (df[category_name2] == category2[c2]) & (df[category_name3] == category3[c3])), :]

          if len(gt_fp) != 0:
            FPR = len(pred_fp) / len(gt_fp)
            print(len(pred_fp),'--' ,len(gt_fp))
            print("False Positive Rate in " + category3[c3] +"/" + category1[c1] + " and "+category2[c2]+ " for " + diseases[d] + " is: " + str(FPR))

          else:
            FPR = np.NaN
            # print("False Positive Rate in " + category1[c1] +"/" + category2[c2] + " and "+category3[c3]+" for " + diseases[d] + " is: N\A")

            print('=======================================================================================================')

        FPR_list.append(round(FPR,3))
        print(FPR_list)
        # break

      if (category_name1 == 'gender')  &  (category_name2 == 'age_decile') & (category_name3 == 'race'):

        if i == 0:
          fpr_60_male = pd.DataFrame(FPR_list, columns=["FPR_60_80_M"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_60_male.reindex(FP_RaceAgeSex.index)], axis=1)

        if i == 1:
          fpr_40_male = pd.DataFrame(FPR_list, columns=["FPR_40_60_M"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_40_male.reindex(FP_RaceAgeSex.index)], axis=1)

        if i ==2:
          fpr_20_male = pd.DataFrame(FPR_list, columns=["FPR_20_40_M"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_20_male.reindex(FP_RaceAgeSex.index)], axis=1)

        if i ==3:
          fpr_80_male = pd.DataFrame(FPR_list, columns=["FPR_80+_M"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_80_male.reindex(FP_RaceAgeSex.index)], axis=1)

        if i ==4:
          fpr_0_male = pd.DataFrame(FPR_list, columns=["FPR_0_20_M"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_0_male.reindex(FP_RaceAgeSex.index)], axis=1)

        if i == 5:
          fpr_60_female = pd.DataFrame(FPR_list, columns=["FPR_60_80_F"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_60_female.reindex(FP_RaceAgeSex.index)], axis=1)

        if i == 6:
          fpr_40_female = pd.DataFrame(FPR_list, columns=["FPR_40_60_F"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_40_female.reindex(FP_RaceAgeSex.index)], axis=1)

        if i ==7:
          fpr_20_female = pd.DataFrame(FPR_list, columns=["FPR_20_40_F"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_20_female.reindex(FP_RaceAgeSex.index)], axis=1)

        if i ==8:
          fpr_80_female = pd.DataFrame(FPR_list, columns=["FPR_80+_F"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_80_female.reindex(FP_RaceAgeSex.index)], axis=1)

        if i ==9:
          fpr_0_female = pd.DataFrame(FPR_list, columns=["FPR_0_20_F"])
          FP_RaceAgeSex = pd.concat([FP_RaceAgeSex, fpr_0_female.reindex(FP_RaceAgeSex.index)], axis=1)

      i+=1


  if (category_name1 == 'gender')  &  (category_name2 == 'age_decile') & (category_name3 == 'race'):
     FP_RaceAgeSex.to_csv(fpr_npr_path_3_group_intersection+"run_"+str(seed)+"FP_RaceAgeSex.csv")

# %%
for seed in seeds:
    
    
    np.random.seed(seed)
    python_random.seed(seed)
    prediction_results_path = "./Prediction_results/"
    fpr_npr_path = "./FPR/SubGroup_FPR/"
    os.makedirs(os.path.dirname(fpr_npr_path), exist_ok=True)
    df = pd.read_csv(f"{prediction_results_path}bipred_{seed}.csv")
    
    
    '''' FPR Calculation '''
    
    for i in range(len(factor)):
        FP_FN_NF_CheXpert(df,diseases,factor[i],factor_str[i],seed,fpr_npr_path)

    '''' Two group FPR '''
    fpr_npr_path_2_group_intersection = "./FPR/Two_Group_Intersection_FPR/"
    os.makedirs(os.path.dirname(fpr_npr_path_2_group_intersection), exist_ok=True)
    
    FP_NF_CheXpert_Inter(df, diseases, gender, 'gender',race,'race',seed,fpr_npr_path_2_group_intersection)
    FP_NF_CheXpert_Inter(df, diseases, gender, 'gender', age_decile, 'age_decile',seed,fpr_npr_path_2_group_intersection)
    FP_NF_CheXpert_Inter(df, diseases, race, 'race', age_decile, 'age_decile',seed,fpr_npr_path_2_group_intersection)

    '''' Three group FPR '''
    fpr_npr_path_3_group_intersection = "./FPR/Three_Group_Intersection_FPR/"
    os.makedirs(os.path.dirname(fpr_npr_path_3_group_intersection), exist_ok=True)

    FP_NF_CheXpert_threegroup_Inter(df, diseases,gender,'gender',age_decile, 'age_decile',race,'race',seed,fpr_npr_path_3_group_intersection)

    print("Seed : ",seed)
# Out:
# FP in CheXpert====================================
# 490 -- 9579 ==== M
# 447 -- 6672 ==== F
# FP in CheXpert====================================
# 346 -- 6526 ==== 60-80
# 298 -- 4770 ==== 40-60
# 127 -- 1797 ==== 20-40
# 159 -- 3033 ==== 80+
# 7 -- 125 ==== 0-20
# FP in CheXpert====================================
# 574 -- 10621 ==== WHITE
# 71 -- 938 ==== BLACK/AFRICAN AMERICAN
# 13 -- 406 ==== HISPANIC/LATINO
# 146 -- 2209 ==== OTHER
# 110 -- 1863 ==== ASIAN
# 23 -- 214 ==== AMERICAN INDIAN/ALASKA NATIVE
# ==================================== Calculating FP in vector embedded CXP====================================
# 305 -- 6337
# False Positive Rate in M/WHITE for No Finding is: 0.048130029982641626
# =======================================================================================================
# 36 -- 466
# False Positive Rate in M/BLACK/AFRICAN AMERICAN for No Finding is: 0.07725321888412018
# =======================================================================================================
# 8 -- 259
# False Positive Rate in M/HISPANIC/LATINO for No Finding is: 0.03088803088803089
# =======================================================================================================
# 67 -- 1236
# False Positive Rate in M/OTHER for No Finding is: 0.054207119741100325
# =======================================================================================================
# 64 -- 1184
# False Positive Rate in M/ASIAN for No Finding is: 0.05405405405405406
# =======================================================================================================
# 10 -- 97
# False Positive Rate in M/AMERICAN INDIAN/ALASKA NATIVE for No Finding is: 0.10309278350515463
# =======================================================================================================
# 269 -- 4284
# False Positive Rate in F/WHITE for No Finding is: 0.06279178338001867
# =======================================================================================================
# 35 -- 472
# False Positive Rate in F/BLACK/AFRICAN AMERICAN for No Finding is: 0.07415254237288135
# =======================================================================================================
# 5 -- 147
# False Positive Rate in F/HISPANIC/LATINO for No Finding is: 0.034013605442176874
# =======================================================================================================
# 79 -- 973
# False Positive Rate in F/OTHER for No Finding is: 0.08119218910585817
# =======================================================================================================
# 46 -- 679
# False Positive Rate in F/ASIAN for No Finding is: 0.06774668630338733
# =======================================================================================================
# 13 -- 117
# False Positive Rate in F/AMERICAN INDIAN/ALASKA NATIVE for No Finding is: 0.1111111111111111
# =======================================================================================================
# ==================================== Calculating FP in vector embedded CXP====================================
# 167 -- 3836
# False Positive Rate in M/60-80 for No Finding is: 0.04353493222106361
# =======================================================================================================
# 166 -- 2820
# False Positive Rate in M/40-60 for No Finding is: 0.058865248226950356
# =======================================================================================================
# 83 -- 1081
# False Positive Rate in M/20-40 for No Finding is: 0.07678075855689177
# =======================================================================================================
# 70 -- 1766
# False Positive Rate in M/80+ for No Finding is: 0.039637599093997736
# =======================================================================================================
# 4 -- 76
# False Positive Rate in M/0-20 for No Finding is: 0.05263157894736842
# =======================================================================================================
# 179 -- 2690
# False Positive Rate in F/60-80 for No Finding is: 0.06654275092936802
# =======================================================================================================
# 132 -- 1950
# False Positive Rate in F/40-60 for No Finding is: 0.06769230769230769
# =======================================================================================================
# 44 -- 716
# False Positive Rate in F/20-40 for No Finding is: 0.061452513966480445
# =======================================================================================================
# 89 -- 1267
# False Positive Rate in F/80+ for No Finding is: 0.0702446724546172
# =======================================================================================================
# 3 -- 49
# False Positive Rate in F/0-20 for No Finding is: 0.061224489795918366
# =======================================================================================================
# ==================================== Calculating FP in vector embedded CXP====================================
# 209 -- 4500
# False Positive Rate in WHITE/60-80 for No Finding is: 0.04644444444444444
# =======================================================================================================
# 178 -- 2819
# False Positive Rate in WHITE/40-60 for No Finding is: 0.06314295849592054
# =======================================================================================================
# 72 -- 979
# False Positive Rate in WHITE/20-40 for No Finding is: 0.0735444330949949
# =======================================================================================================
# 114 -- 2255
# False Positive Rate in WHITE/80+ for No Finding is: 0.05055432372505543
# =======================================================================================================
# 1 -- 68
# False Positive Rate in WHITE/0-20 for No Finding is: 0.014705882352941176
# =======================================================================================================
# 18 -- 297
# False Positive Rate in BLACK/AFRICAN AMERICAN/60-80 for No Finding is: 0.06060606060606061
# =======================================================================================================
# 32 -- 337
# False Positive Rate in BLACK/AFRICAN AMERICAN/40-60 for No Finding is: 0.09495548961424333
# =======================================================================================================
# 9 -- 128
# False Positive Rate in BLACK/AFRICAN AMERICAN/20-40 for No Finding is: 0.0703125
# =======================================================================================================
# 12 -- 147
# False Positive Rate in BLACK/AFRICAN AMERICAN/80+ for No Finding is: 0.08163265306122448
# =======================================================================================================
# 0 -- 29
# False Positive Rate in BLACK/AFRICAN AMERICAN/0-20 for No Finding is: 0.0
# =======================================================================================================
# 3 -- 114
# False Positive Rate in HISPANIC/LATINO/60-80 for No Finding is: 0.02631578947368421
# =======================================================================================================
# 5 -- 141
# False Positive Rate in HISPANIC/LATINO/40-60 for No Finding is: 0.03546099290780142
# =======================================================================================================
# 2 -- 105
# False Positive Rate in HISPANIC/LATINO/20-40 for No Finding is: 0.01904761904761905
# =======================================================================================================
# 2 -- 43
# False Positive Rate in HISPANIC/LATINO/80+ for No Finding is: 0.046511627906976744
# =======================================================================================================
# 1 -- 3
# False Positive Rate in HISPANIC/LATINO/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# 53 -- 731
# False Positive Rate in OTHER/60-80 for No Finding is: 0.07250341997264022
# =======================================================================================================
# 41 -- 918
# False Positive Rate in OTHER/40-60 for No Finding is: 0.044662309368191724
# =======================================================================================================
# 27 -- 336
# False Positive Rate in OTHER/20-40 for No Finding is: 0.08035714285714286
# =======================================================================================================
# 21 -- 212
# False Positive Rate in OTHER/80+ for No Finding is: 0.09905660377358491
# =======================================================================================================
# 4 -- 12
# False Positive Rate in OTHER/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# 54 -- 798
# False Positive Rate in ASIAN/60-80 for No Finding is: 0.06766917293233082
# =======================================================================================================
# 36 -- 503
# False Positive Rate in ASIAN/40-60 for No Finding is: 0.07157057654075547
# =======================================================================================================
# 10 -- 187
# False Positive Rate in ASIAN/20-40 for No Finding is: 0.053475935828877004
# =======================================================================================================
# 10 -- 365
# False Positive Rate in ASIAN/80+ for No Finding is: 0.0273972602739726
# =======================================================================================================
# 0 -- 10
# False Positive Rate in ASIAN/0-20 for No Finding is: 0.0
# =======================================================================================================
# 9 -- 86
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/60-80 for No Finding is: 0.10465116279069768
# =======================================================================================================
# 6 -- 52
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/40-60 for No Finding is: 0.11538461538461539
# =======================================================================================================
# 7 -- 62
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/20-40 for No Finding is: 0.11290322580645161
# =======================================================================================================
# 0 -- 11
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/80+ for No Finding is: 0.0
# =======================================================================================================
# 1 -- 3
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# ==================================== Calculating FP in vector embedded mimic cxr====================================
# 108 -- 2686
# False Positive Rate in WHITE/M and 60-80 for No Finding is: 0.040208488458674606
# [0.04]
# 7 -- 153
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 60-80 for No Finding is: 0.0457516339869281
# [0.04, 0.046]
# 1 -- 59
# False Positive Rate in HISPANIC/LATINO/M and 60-80 for No Finding is: 0.01694915254237288
# [0.04, 0.046, 0.017]
# 18 -- 395
# False Positive Rate in OTHER/M and 60-80 for No Finding is: 0.04556962025316456
# [0.04, 0.046, 0.017, 0.046]
# 31 -- 521
# False Positive Rate in ASIAN/M and 60-80 for No Finding is: 0.05950095969289827
# [0.04, 0.046, 0.017, 0.046, 0.06]
# 2 -- 22
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 60-80 for No Finding is: 0.09090909090909091
# [0.04, 0.046, 0.017, 0.046, 0.06, 0.091]
# 99 -- 1687
# False Positive Rate in WHITE/M and 40-60 for No Finding is: 0.05868405453467694
# [0.059]
# 16 -- 188
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 40-60 for No Finding is: 0.0851063829787234
# [0.059, 0.085]
# 3 -- 72
# False Positive Rate in HISPANIC/LATINO/M and 40-60 for No Finding is: 0.041666666666666664
# [0.059, 0.085, 0.042]
# 21 -- 499
# False Positive Rate in OTHER/M and 40-60 for No Finding is: 0.04208416833667335
# [0.059, 0.085, 0.042, 0.042]
# 23 -- 346
# False Positive Rate in ASIAN/M and 40-60 for No Finding is: 0.06647398843930635
# [0.059, 0.085, 0.042, 0.042, 0.066]
# 4 -- 28
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 40-60 for No Finding is: 0.14285714285714285
# [0.059, 0.085, 0.042, 0.042, 0.066, 0.143]
# 49 -- 592
# False Positive Rate in WHITE/M and 20-40 for No Finding is: 0.08277027027027027
# [0.083]
# 6 -- 54
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 20-40 for No Finding is: 0.1111111111111111
# [0.083, 0.111]
# 2 -- 91
# False Positive Rate in HISPANIC/LATINO/M and 20-40 for No Finding is: 0.02197802197802198
# [0.083, 0.111, 0.022]
# 18 -- 210
# False Positive Rate in OTHER/M and 20-40 for No Finding is: 0.08571428571428572
# [0.083, 0.111, 0.022, 0.086]
# 5 -- 93
# False Positive Rate in ASIAN/M and 20-40 for No Finding is: 0.053763440860215055
# [0.083, 0.111, 0.022, 0.086, 0.054]
# 3 -- 41
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 20-40 for No Finding is: 0.07317073170731707
# [0.083, 0.111, 0.022, 0.086, 0.054, 0.073]
# 48 -- 1342
# False Positive Rate in WHITE/M and 80+ for No Finding is: 0.03576751117734724
# [0.036]
# 7 -- 46
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 80+ for No Finding is: 0.15217391304347827
# [0.036, 0.152]
# 1 -- 35
# False Positive Rate in HISPANIC/LATINO/M and 80+ for No Finding is: 0.02857142857142857
# [0.036, 0.152, 0.029]
# 9 -- 124
# False Positive Rate in OTHER/M and 80+ for No Finding is: 0.07258064516129033
# [0.036, 0.152, 0.029, 0.073]
# 5 -- 214
# False Positive Rate in ASIAN/M and 80+ for No Finding is: 0.02336448598130841
# [0.036, 0.152, 0.029, 0.073, 0.023]
# 0 -- 5
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 80+ for No Finding is: 0.0
# [0.036, 0.152, 0.029, 0.073, 0.023, 0.0]
# 1 -- 30
# False Positive Rate in WHITE/M and 0-20 for No Finding is: 0.03333333333333333
# [0.033]
# 0 -- 25
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 0-20 for No Finding is: 0.0
# [0.033, 0.0]
# 1 -- 2
# False Positive Rate in HISPANIC/LATINO/M and 0-20 for No Finding is: 0.5
# [0.033, 0.0, 0.5]
# 1 -- 8
# False Positive Rate in OTHER/M and 0-20 for No Finding is: 0.125
# [0.033, 0.0, 0.5, 0.125]
# 0 -- 10
# False Positive Rate in ASIAN/M and 0-20 for No Finding is: 0.0
# [0.033, 0.0, 0.5, 0.125, 0.0]
# 1 -- 1
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 0-20 for No Finding is: 1.0
# [0.033, 0.0, 0.5, 0.125, 0.0, 1.0]
# 101 -- 1814
# False Positive Rate in WHITE/F and 60-80 for No Finding is: 0.05567805953693495
# [0.056]
# 11 -- 144
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 60-80 for No Finding is: 0.0763888888888889
# [0.056, 0.076]
# 2 -- 55
# False Positive Rate in HISPANIC/LATINO/F and 60-80 for No Finding is: 0.03636363636363636
# [0.056, 0.076, 0.036]
# 35 -- 336
# False Positive Rate in OTHER/F and 60-80 for No Finding is: 0.10416666666666667
# [0.056, 0.076, 0.036, 0.104]
# 23 -- 277
# False Positive Rate in ASIAN/F and 60-80 for No Finding is: 0.08303249097472924
# [0.056, 0.076, 0.036, 0.104, 0.083]
# 7 -- 64
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 60-80 for No Finding is: 0.109375
# [0.056, 0.076, 0.036, 0.104, 0.083, 0.109]
# 79 -- 1132
# False Positive Rate in WHITE/F and 40-60 for No Finding is: 0.06978798586572438
# [0.07]
# 16 -- 149
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 40-60 for No Finding is: 0.10738255033557047
# [0.07, 0.107]
# 2 -- 69
# False Positive Rate in HISPANIC/LATINO/F and 40-60 for No Finding is: 0.028985507246376812
# [0.07, 0.107, 0.029]
# 20 -- 419
# False Positive Rate in OTHER/F and 40-60 for No Finding is: 0.0477326968973747
# [0.07, 0.107, 0.029, 0.048]
# 13 -- 157
# False Positive Rate in ASIAN/F and 40-60 for No Finding is: 0.08280254777070063
# [0.07, 0.107, 0.029, 0.048, 0.083]
# 2 -- 24
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 40-60 for No Finding is: 0.08333333333333333
# [0.07, 0.107, 0.029, 0.048, 0.083, 0.083]
# 23 -- 387
# False Positive Rate in WHITE/F and 20-40 for No Finding is: 0.059431524547803614
# [0.059]
# 3 -- 74
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 20-40 for No Finding is: 0.04054054054054054
# [0.059, 0.041]
# 0 -- 14
# False Positive Rate in HISPANIC/LATINO/F and 20-40 for No Finding is: 0.0
# [0.059, 0.041, 0.0]
# 9 -- 126
# False Positive Rate in OTHER/F and 20-40 for No Finding is: 0.07142857142857142
# [0.059, 0.041, 0.0, 0.071]
# 5 -- 94
# False Positive Rate in ASIAN/F and 20-40 for No Finding is: 0.05319148936170213
# [0.059, 0.041, 0.0, 0.071, 0.053]
# 4 -- 21
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 20-40 for No Finding is: 0.19047619047619047
# [0.059, 0.041, 0.0, 0.071, 0.053, 0.19]
# 66 -- 913
# False Positive Rate in WHITE/F and 80+ for No Finding is: 0.07228915662650602
# [0.072]
# 5 -- 101
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 80+ for No Finding is: 0.04950495049504951
# [0.072, 0.05]
# 1 -- 8
# False Positive Rate in HISPANIC/LATINO/F and 80+ for No Finding is: 0.125
# [0.072, 0.05, 0.125]
# 12 -- 88
# False Positive Rate in OTHER/F and 80+ for No Finding is: 0.13636363636363635
# [0.072, 0.05, 0.125, 0.136]
# 5 -- 151
# False Positive Rate in ASIAN/F and 80+ for No Finding is: 0.033112582781456956
# [0.072, 0.05, 0.125, 0.136, 0.033]
# 0 -- 6
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 80+ for No Finding is: 0.0
# [0.072, 0.05, 0.125, 0.136, 0.033, 0.0]
# 0 -- 38
# False Positive Rate in WHITE/F and 0-20 for No Finding is: 0.0
# [0.0]
# 0 -- 4
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 0-20 for No Finding is: 0.0
# [0.0, 0.0]
# 0 -- 1
# False Positive Rate in HISPANIC/LATINO/F and 0-20 for No Finding is: 0.0
# [0.0, 0.0, 0.0]
# 3 -- 4
# False Positive Rate in OTHER/F and 0-20 for No Finding is: 0.75
# [0.0, 0.0, 0.0, 0.75]
# =======================================================================================================
# [0.0, 0.0, 0.0, 0.75, nan]
# 0 -- 2
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 0-20 for No Finding is: 0.0
# [0.0, 0.0, 0.0, 0.75, nan, 0.0]
# Seed :  19
# FP in CheXpert====================================
# 562 -- 9579 ==== M
# 495 -- 6672 ==== F
# FP in CheXpert====================================
# 383 -- 6526 ==== 60-80
# 331 -- 4770 ==== 40-60
# 148 -- 1797 ==== 20-40
# 186 -- 3033 ==== 80+
# 9 -- 125 ==== 0-20
# FP in CheXpert====================================
# 659 -- 10621 ==== WHITE
# 74 -- 938 ==== BLACK/AFRICAN AMERICAN
# 14 -- 406 ==== HISPANIC/LATINO
# 168 -- 2209 ==== OTHER
# 120 -- 1863 ==== ASIAN
# 22 -- 214 ==== AMERICAN INDIAN/ALASKA NATIVE
# ==================================== Calculating FP in vector embedded CXP====================================
# 355 -- 6337
# False Positive Rate in M/WHITE for No Finding is: 0.05602019883225501
# =======================================================================================================
# 37 -- 466
# False Positive Rate in M/BLACK/AFRICAN AMERICAN for No Finding is: 0.07939914163090128
# =======================================================================================================
# 8 -- 259
# False Positive Rate in M/HISPANIC/LATINO for No Finding is: 0.03088803088803089
# =======================================================================================================
# 83 -- 1236
# False Positive Rate in M/OTHER for No Finding is: 0.06715210355987054
# =======================================================================================================
# 70 -- 1184
# False Positive Rate in M/ASIAN for No Finding is: 0.05912162162162162
# =======================================================================================================
# 9 -- 97
# False Positive Rate in M/AMERICAN INDIAN/ALASKA NATIVE for No Finding is: 0.09278350515463918
# =======================================================================================================
# 304 -- 4284
# False Positive Rate in F/WHITE for No Finding is: 0.07096171802054155
# =======================================================================================================
# 37 -- 472
# False Positive Rate in F/BLACK/AFRICAN AMERICAN for No Finding is: 0.07838983050847458
# =======================================================================================================
# 6 -- 147
# False Positive Rate in F/HISPANIC/LATINO for No Finding is: 0.04081632653061224
# =======================================================================================================
# 85 -- 973
# False Positive Rate in F/OTHER for No Finding is: 0.08735868448098665
# =======================================================================================================
# 50 -- 679
# False Positive Rate in F/ASIAN for No Finding is: 0.07363770250368189
# =======================================================================================================
# 13 -- 117
# False Positive Rate in F/AMERICAN INDIAN/ALASKA NATIVE for No Finding is: 0.1111111111111111
# =======================================================================================================
# ==================================== Calculating FP in vector embedded CXP====================================
# 193 -- 3836
# False Positive Rate in M/60-80 for No Finding is: 0.05031282586027112
# =======================================================================================================
# 186 -- 2820
# False Positive Rate in M/40-60 for No Finding is: 0.06595744680851064
# =======================================================================================================
# 98 -- 1081
# False Positive Rate in M/20-40 for No Finding is: 0.09065679925994449
# =======================================================================================================
# 79 -- 1766
# False Positive Rate in M/80+ for No Finding is: 0.04473386183465459
# =======================================================================================================
# 6 -- 76
# False Positive Rate in M/0-20 for No Finding is: 0.07894736842105263
# =======================================================================================================
# 190 -- 2690
# False Positive Rate in F/60-80 for No Finding is: 0.07063197026022305
# =======================================================================================================
# 145 -- 1950
# False Positive Rate in F/40-60 for No Finding is: 0.07435897435897436
# =======================================================================================================
# 50 -- 716
# False Positive Rate in F/20-40 for No Finding is: 0.06983240223463687
# =======================================================================================================
# 107 -- 1267
# False Positive Rate in F/80+ for No Finding is: 0.08445146014206788
# =======================================================================================================
# 3 -- 49
# False Positive Rate in F/0-20 for No Finding is: 0.061224489795918366
# =======================================================================================================
# ==================================== Calculating FP in vector embedded CXP====================================
# 235 -- 4500
# False Positive Rate in WHITE/60-80 for No Finding is: 0.052222222222222225
# =======================================================================================================
# 197 -- 2819
# False Positive Rate in WHITE/40-60 for No Finding is: 0.06988293721177723
# =======================================================================================================
# 86 -- 979
# False Positive Rate in WHITE/20-40 for No Finding is: 0.08784473953013279
# =======================================================================================================
# 138 -- 2255
# False Positive Rate in WHITE/80+ for No Finding is: 0.06119733924611973
# =======================================================================================================
# 3 -- 68
# False Positive Rate in WHITE/0-20 for No Finding is: 0.04411764705882353
# =======================================================================================================
# 21 -- 297
# False Positive Rate in BLACK/AFRICAN AMERICAN/60-80 for No Finding is: 0.0707070707070707
# =======================================================================================================
# 32 -- 337
# False Positive Rate in BLACK/AFRICAN AMERICAN/40-60 for No Finding is: 0.09495548961424333
# =======================================================================================================
# 10 -- 128
# False Positive Rate in BLACK/AFRICAN AMERICAN/20-40 for No Finding is: 0.078125
# =======================================================================================================
# 11 -- 147
# False Positive Rate in BLACK/AFRICAN AMERICAN/80+ for No Finding is: 0.07482993197278912
# =======================================================================================================
# 0 -- 29
# False Positive Rate in BLACK/AFRICAN AMERICAN/0-20 for No Finding is: 0.0
# =======================================================================================================
# 2 -- 114
# False Positive Rate in HISPANIC/LATINO/60-80 for No Finding is: 0.017543859649122806
# =======================================================================================================
# 7 -- 141
# False Positive Rate in HISPANIC/LATINO/40-60 for No Finding is: 0.04964539007092199
# =======================================================================================================
# 2 -- 105
# False Positive Rate in HISPANIC/LATINO/20-40 for No Finding is: 0.01904761904761905
# =======================================================================================================
# 2 -- 43
# False Positive Rate in HISPANIC/LATINO/80+ for No Finding is: 0.046511627906976744
# =======================================================================================================
# 1 -- 3
# False Positive Rate in HISPANIC/LATINO/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# 58 -- 731
# False Positive Rate in OTHER/60-80 for No Finding is: 0.07934336525307797
# =======================================================================================================
# 52 -- 918
# False Positive Rate in OTHER/40-60 for No Finding is: 0.05664488017429194
# =======================================================================================================
# 30 -- 336
# False Positive Rate in OTHER/20-40 for No Finding is: 0.08928571428571429
# =======================================================================================================
# 24 -- 212
# False Positive Rate in OTHER/80+ for No Finding is: 0.11320754716981132
# =======================================================================================================
# 4 -- 12
# False Positive Rate in OTHER/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# 59 -- 798
# False Positive Rate in ASIAN/60-80 for No Finding is: 0.07393483709273183
# =======================================================================================================
# 38 -- 503
# False Positive Rate in ASIAN/40-60 for No Finding is: 0.07554671968190854
# =======================================================================================================
# 12 -- 187
# False Positive Rate in ASIAN/20-40 for No Finding is: 0.06417112299465241
# =======================================================================================================
# 11 -- 365
# False Positive Rate in ASIAN/80+ for No Finding is: 0.030136986301369864
# =======================================================================================================
# 0 -- 10
# False Positive Rate in ASIAN/0-20 for No Finding is: 0.0
# =======================================================================================================
# 8 -- 86
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/60-80 for No Finding is: 0.09302325581395349
# =======================================================================================================
# 5 -- 52
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/40-60 for No Finding is: 0.09615384615384616
# =======================================================================================================
# 8 -- 62
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/20-40 for No Finding is: 0.12903225806451613
# =======================================================================================================
# 0 -- 11
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/80+ for No Finding is: 0.0
# =======================================================================================================
# 1 -- 3
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# ==================================== Calculating FP in vector embedded mimic cxr====================================
# 126 -- 2686
# False Positive Rate in WHITE/M and 60-80 for No Finding is: 0.04690990320178704
# [0.047]
# 10 -- 153
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 60-80 for No Finding is: 0.06535947712418301
# [0.047, 0.065]
# 0 -- 59
# False Positive Rate in HISPANIC/LATINO/M and 60-80 for No Finding is: 0.0
# [0.047, 0.065, 0.0]
# 21 -- 395
# False Positive Rate in OTHER/M and 60-80 for No Finding is: 0.053164556962025315
# [0.047, 0.065, 0.0, 0.053]
# 35 -- 521
# False Positive Rate in ASIAN/M and 60-80 for No Finding is: 0.0671785028790787
# [0.047, 0.065, 0.0, 0.053, 0.067]
# 1 -- 22
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 60-80 for No Finding is: 0.045454545454545456
# [0.047, 0.065, 0.0, 0.053, 0.067, 0.045]
# 109 -- 1687
# False Positive Rate in WHITE/M and 40-60 for No Finding is: 0.06461173681090694
# [0.065]
# 15 -- 188
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 40-60 for No Finding is: 0.0797872340425532
# [0.065, 0.08]
# 4 -- 72
# False Positive Rate in HISPANIC/LATINO/M and 40-60 for No Finding is: 0.05555555555555555
# [0.065, 0.08, 0.056]
# 31 -- 499
# False Positive Rate in OTHER/M and 40-60 for No Finding is: 0.06212424849699399
# [0.065, 0.08, 0.056, 0.062]
# 24 -- 346
# False Positive Rate in ASIAN/M and 40-60 for No Finding is: 0.06936416184971098
# [0.065, 0.08, 0.056, 0.062, 0.069]
# 3 -- 28
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 40-60 for No Finding is: 0.10714285714285714
# [0.065, 0.08, 0.056, 0.062, 0.069, 0.107]
# 61 -- 592
# False Positive Rate in WHITE/M and 20-40 for No Finding is: 0.10304054054054054
# [0.103]
# 6 -- 54
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 20-40 for No Finding is: 0.1111111111111111
# [0.103, 0.111]
# 2 -- 91
# False Positive Rate in HISPANIC/LATINO/M and 20-40 for No Finding is: 0.02197802197802198
# [0.103, 0.111, 0.022]
# 20 -- 210
# False Positive Rate in OTHER/M and 20-40 for No Finding is: 0.09523809523809523
# [0.103, 0.111, 0.022, 0.095]
# 5 -- 93
# False Positive Rate in ASIAN/M and 20-40 for No Finding is: 0.053763440860215055
# [0.103, 0.111, 0.022, 0.095, 0.054]
# 4 -- 41
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 20-40 for No Finding is: 0.0975609756097561
# [0.103, 0.111, 0.022, 0.095, 0.054, 0.098]
# 56 -- 1342
# False Positive Rate in WHITE/M and 80+ for No Finding is: 0.041728763040238454
# [0.042]
# 6 -- 46
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 80+ for No Finding is: 0.13043478260869565
# [0.042, 0.13]
# 1 -- 35
# False Positive Rate in HISPANIC/LATINO/M and 80+ for No Finding is: 0.02857142857142857
# [0.042, 0.13, 0.029]
# 10 -- 124
# False Positive Rate in OTHER/M and 80+ for No Finding is: 0.08064516129032258
# [0.042, 0.13, 0.029, 0.081]
# 6 -- 214
# False Positive Rate in ASIAN/M and 80+ for No Finding is: 0.028037383177570093
# [0.042, 0.13, 0.029, 0.081, 0.028]
# 0 -- 5
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 80+ for No Finding is: 0.0
# [0.042, 0.13, 0.029, 0.081, 0.028, 0.0]
# 3 -- 30
# False Positive Rate in WHITE/M and 0-20 for No Finding is: 0.1
# [0.1]
# 0 -- 25
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 0-20 for No Finding is: 0.0
# [0.1, 0.0]
# 1 -- 2
# False Positive Rate in HISPANIC/LATINO/M and 0-20 for No Finding is: 0.5
# [0.1, 0.0, 0.5]
# 1 -- 8
# False Positive Rate in OTHER/M and 0-20 for No Finding is: 0.125
# [0.1, 0.0, 0.5, 0.125]
# 0 -- 10
# False Positive Rate in ASIAN/M and 0-20 for No Finding is: 0.0
# [0.1, 0.0, 0.5, 0.125, 0.0]
# 1 -- 1
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 0-20 for No Finding is: 1.0
# [0.1, 0.0, 0.5, 0.125, 0.0, 1.0]
# 109 -- 1814
# False Positive Rate in WHITE/F and 60-80 for No Finding is: 0.060088202866593166
# [0.06]
# 11 -- 144
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 60-80 for No Finding is: 0.0763888888888889
# [0.06, 0.076]
# 2 -- 55
# False Positive Rate in HISPANIC/LATINO/F and 60-80 for No Finding is: 0.03636363636363636
# [0.06, 0.076, 0.036]
# 37 -- 336
# False Positive Rate in OTHER/F and 60-80 for No Finding is: 0.11011904761904762
# [0.06, 0.076, 0.036, 0.11]
# 24 -- 277
# False Positive Rate in ASIAN/F and 60-80 for No Finding is: 0.08664259927797834
# [0.06, 0.076, 0.036, 0.11, 0.087]
# 7 -- 64
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 60-80 for No Finding is: 0.109375
# [0.06, 0.076, 0.036, 0.11, 0.087, 0.109]
# 88 -- 1132
# False Positive Rate in WHITE/F and 40-60 for No Finding is: 0.07773851590106007
# [0.078]
# 17 -- 149
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 40-60 for No Finding is: 0.11409395973154363
# [0.078, 0.114]
# 3 -- 69
# False Positive Rate in HISPANIC/LATINO/F and 40-60 for No Finding is: 0.043478260869565216
# [0.078, 0.114, 0.043]
# 21 -- 419
# False Positive Rate in OTHER/F and 40-60 for No Finding is: 0.050119331742243436
# [0.078, 0.114, 0.043, 0.05]
# 14 -- 157
# False Positive Rate in ASIAN/F and 40-60 for No Finding is: 0.08917197452229299
# [0.078, 0.114, 0.043, 0.05, 0.089]
# 2 -- 24
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 40-60 for No Finding is: 0.08333333333333333
# [0.078, 0.114, 0.043, 0.05, 0.089, 0.083]
# 25 -- 387
# False Positive Rate in WHITE/F and 20-40 for No Finding is: 0.06459948320413436
# [0.065]
# 4 -- 74
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 20-40 for No Finding is: 0.05405405405405406
# [0.065, 0.054]
# 0 -- 14
# False Positive Rate in HISPANIC/LATINO/F and 20-40 for No Finding is: 0.0
# [0.065, 0.054, 0.0]
# 10 -- 126
# False Positive Rate in OTHER/F and 20-40 for No Finding is: 0.07936507936507936
# [0.065, 0.054, 0.0, 0.079]
# 7 -- 94
# False Positive Rate in ASIAN/F and 20-40 for No Finding is: 0.07446808510638298
# [0.065, 0.054, 0.0, 0.079, 0.074]
# 4 -- 21
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 20-40 for No Finding is: 0.19047619047619047
# [0.065, 0.054, 0.0, 0.079, 0.074, 0.19]
# 82 -- 913
# False Positive Rate in WHITE/F and 80+ for No Finding is: 0.08981380065717415
# [0.09]
# 5 -- 101
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 80+ for No Finding is: 0.04950495049504951
# [0.09, 0.05]
# 1 -- 8
# False Positive Rate in HISPANIC/LATINO/F and 80+ for No Finding is: 0.125
# [0.09, 0.05, 0.125]
# 14 -- 88
# False Positive Rate in OTHER/F and 80+ for No Finding is: 0.1590909090909091
# [0.09, 0.05, 0.125, 0.159]
# 5 -- 151
# False Positive Rate in ASIAN/F and 80+ for No Finding is: 0.033112582781456956
# [0.09, 0.05, 0.125, 0.159, 0.033]
# 0 -- 6
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 80+ for No Finding is: 0.0
# [0.09, 0.05, 0.125, 0.159, 0.033, 0.0]
# 0 -- 38
# False Positive Rate in WHITE/F and 0-20 for No Finding is: 0.0
# [0.0]
# 0 -- 4
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 0-20 for No Finding is: 0.0
# [0.0, 0.0]
# 0 -- 1
# False Positive Rate in HISPANIC/LATINO/F and 0-20 for No Finding is: 0.0
# [0.0, 0.0, 0.0]
# 3 -- 4
# False Positive Rate in OTHER/F and 0-20 for No Finding is: 0.75
# [0.0, 0.0, 0.0, 0.75]
# =======================================================================================================
# [0.0, 0.0, 0.0, 0.75, nan]
# 0 -- 2
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 0-20 for No Finding is: 0.0
# [0.0, 0.0, 0.0, 0.75, nan, 0.0]
# Seed :  31
# FP in CheXpert====================================
# 550 -- 9579 ==== M
# 430 -- 6672 ==== F
# FP in CheXpert====================================
# 359 -- 6526 ==== 60-80
# 309 -- 4770 ==== 40-60
# 140 -- 1797 ==== 20-40
# 164 -- 3033 ==== 80+
# 8 -- 125 ==== 0-20
# FP in CheXpert====================================
# 598 -- 10621 ==== WHITE
# 76 -- 938 ==== BLACK/AFRICAN AMERICAN
# 12 -- 406 ==== HISPANIC/LATINO
# 158 -- 2209 ==== OTHER
# 116 -- 1863 ==== ASIAN
# 20 -- 214 ==== AMERICAN INDIAN/ALASKA NATIVE
# ==================================== Calculating FP in vector embedded CXP====================================
# 343 -- 6337
# False Positive Rate in M/WHITE for No Finding is: 0.0541265583083478
# =======================================================================================================
# 41 -- 466
# False Positive Rate in M/BLACK/AFRICAN AMERICAN for No Finding is: 0.08798283261802575
# =======================================================================================================
# 8 -- 259
# False Positive Rate in M/HISPANIC/LATINO for No Finding is: 0.03088803088803089
# =======================================================================================================
# 81 -- 1236
# False Positive Rate in M/OTHER for No Finding is: 0.06553398058252427
# =======================================================================================================
# 68 -- 1184
# False Positive Rate in M/ASIAN for No Finding is: 0.057432432432432436
# =======================================================================================================
# 9 -- 97
# False Positive Rate in M/AMERICAN INDIAN/ALASKA NATIVE for No Finding is: 0.09278350515463918
# =======================================================================================================
# 255 -- 4284
# False Positive Rate in F/WHITE for No Finding is: 0.05952380952380952
# =======================================================================================================
# 35 -- 472
# False Positive Rate in F/BLACK/AFRICAN AMERICAN for No Finding is: 0.07415254237288135
# =======================================================================================================
# 4 -- 147
# False Positive Rate in F/HISPANIC/LATINO for No Finding is: 0.027210884353741496
# =======================================================================================================
# 77 -- 973
# False Positive Rate in F/OTHER for No Finding is: 0.07913669064748201
# =======================================================================================================
# 48 -- 679
# False Positive Rate in F/ASIAN for No Finding is: 0.07069219440353461
# =======================================================================================================
# 11 -- 117
# False Positive Rate in F/AMERICAN INDIAN/ALASKA NATIVE for No Finding is: 0.09401709401709402
# =======================================================================================================
# ==================================== Calculating FP in vector embedded CXP====================================
# 191 -- 3836
# False Positive Rate in M/60-80 for No Finding is: 0.049791449426485924
# =======================================================================================================
# 182 -- 2820
# False Positive Rate in M/40-60 for No Finding is: 0.06453900709219858
# =======================================================================================================
# 93 -- 1081
# False Positive Rate in M/20-40 for No Finding is: 0.08603145235892692
# =======================================================================================================
# 79 -- 1766
# False Positive Rate in M/80+ for No Finding is: 0.04473386183465459
# =======================================================================================================
# 5 -- 76
# False Positive Rate in M/0-20 for No Finding is: 0.06578947368421052
# =======================================================================================================
# 168 -- 2690
# False Positive Rate in F/60-80 for No Finding is: 0.06245353159851301
# =======================================================================================================
# 127 -- 1950
# False Positive Rate in F/40-60 for No Finding is: 0.06512820512820512
# =======================================================================================================
# 47 -- 716
# False Positive Rate in F/20-40 for No Finding is: 0.06564245810055866
# =======================================================================================================
# 85 -- 1267
# False Positive Rate in F/80+ for No Finding is: 0.06708760852407261
# =======================================================================================================
# 3 -- 49
# False Positive Rate in F/0-20 for No Finding is: 0.061224489795918366
# =======================================================================================================
# ==================================== Calculating FP in vector embedded CXP====================================
# 216 -- 4500
# False Positive Rate in WHITE/60-80 for No Finding is: 0.048
# =======================================================================================================
# 184 -- 2819
# False Positive Rate in WHITE/40-60 for No Finding is: 0.0652713728272437
# =======================================================================================================
# 79 -- 979
# False Positive Rate in WHITE/20-40 for No Finding is: 0.08069458631256383
# =======================================================================================================
# 117 -- 2255
# False Positive Rate in WHITE/80+ for No Finding is: 0.05188470066518847
# =======================================================================================================
# 2 -- 68
# False Positive Rate in WHITE/0-20 for No Finding is: 0.029411764705882353
# =======================================================================================================
# 20 -- 297
# False Positive Rate in BLACK/AFRICAN AMERICAN/60-80 for No Finding is: 0.06734006734006734
# =======================================================================================================
# 32 -- 337
# False Positive Rate in BLACK/AFRICAN AMERICAN/40-60 for No Finding is: 0.09495548961424333
# =======================================================================================================
# 11 -- 128
# False Positive Rate in BLACK/AFRICAN AMERICAN/20-40 for No Finding is: 0.0859375
# =======================================================================================================
# 13 -- 147
# False Positive Rate in BLACK/AFRICAN AMERICAN/80+ for No Finding is: 0.08843537414965986
# =======================================================================================================
# 0 -- 29
# False Positive Rate in BLACK/AFRICAN AMERICAN/0-20 for No Finding is: 0.0
# =======================================================================================================
# 3 -- 114
# False Positive Rate in HISPANIC/LATINO/60-80 for No Finding is: 0.02631578947368421
# =======================================================================================================
# 4 -- 141
# False Positive Rate in HISPANIC/LATINO/40-60 for No Finding is: 0.028368794326241134
# =======================================================================================================
# 2 -- 105
# False Positive Rate in HISPANIC/LATINO/20-40 for No Finding is: 0.01904761904761905
# =======================================================================================================
# 2 -- 43
# False Positive Rate in HISPANIC/LATINO/80+ for No Finding is: 0.046511627906976744
# =======================================================================================================
# 1 -- 3
# False Positive Rate in HISPANIC/LATINO/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# 54 -- 731
# False Positive Rate in OTHER/60-80 for No Finding is: 0.07387140902872777
# =======================================================================================================
# 49 -- 918
# False Positive Rate in OTHER/40-60 for No Finding is: 0.05337690631808279
# =======================================================================================================
# 30 -- 336
# False Positive Rate in OTHER/20-40 for No Finding is: 0.08928571428571429
# =======================================================================================================
# 21 -- 212
# False Positive Rate in OTHER/80+ for No Finding is: 0.09905660377358491
# =======================================================================================================
# 4 -- 12
# False Positive Rate in OTHER/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# 59 -- 798
# False Positive Rate in ASIAN/60-80 for No Finding is: 0.07393483709273183
# =======================================================================================================
# 35 -- 503
# False Positive Rate in ASIAN/40-60 for No Finding is: 0.06958250497017893
# =======================================================================================================
# 11 -- 187
# False Positive Rate in ASIAN/20-40 for No Finding is: 0.058823529411764705
# =======================================================================================================
# 11 -- 365
# False Positive Rate in ASIAN/80+ for No Finding is: 0.030136986301369864
# =======================================================================================================
# 0 -- 10
# False Positive Rate in ASIAN/0-20 for No Finding is: 0.0
# =======================================================================================================
# 7 -- 86
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/60-80 for No Finding is: 0.08139534883720931
# =======================================================================================================
# 5 -- 52
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/40-60 for No Finding is: 0.09615384615384616
# =======================================================================================================
# 7 -- 62
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/20-40 for No Finding is: 0.11290322580645161
# =======================================================================================================
# 0 -- 11
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/80+ for No Finding is: 0.0
# =======================================================================================================
# 1 -- 3
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# ==================================== Calculating FP in vector embedded mimic cxr====================================
# 124 -- 2686
# False Positive Rate in WHITE/M and 60-80 for No Finding is: 0.04616530156366344
# [0.046]
# 10 -- 153
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 60-80 for No Finding is: 0.06535947712418301
# [0.046, 0.065]
# 1 -- 59
# False Positive Rate in HISPANIC/LATINO/M and 60-80 for No Finding is: 0.01694915254237288
# [0.046, 0.065, 0.017]
# 19 -- 395
# False Positive Rate in OTHER/M and 60-80 for No Finding is: 0.04810126582278481
# [0.046, 0.065, 0.017, 0.048]
# 35 -- 521
# False Positive Rate in ASIAN/M and 60-80 for No Finding is: 0.0671785028790787
# [0.046, 0.065, 0.017, 0.048, 0.067]
# 2 -- 22
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 60-80 for No Finding is: 0.09090909090909091
# [0.046, 0.065, 0.017, 0.048, 0.067, 0.091]
# 106 -- 1687
# False Positive Rate in WHITE/M and 40-60 for No Finding is: 0.06283343212803794
# [0.063]
# 17 -- 188
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 40-60 for No Finding is: 0.09042553191489362
# [0.063, 0.09]
# 3 -- 72
# False Positive Rate in HISPANIC/LATINO/M and 40-60 for No Finding is: 0.041666666666666664
# [0.063, 0.09, 0.042]
# 30 -- 499
# False Positive Rate in OTHER/M and 40-60 for No Finding is: 0.06012024048096192
# [0.063, 0.09, 0.042, 0.06]
# 23 -- 346
# False Positive Rate in ASIAN/M and 40-60 for No Finding is: 0.06647398843930635
# [0.063, 0.09, 0.042, 0.06, 0.066]
# 3 -- 28
# ...
# False Positive Rate in F/BLACK/AFRICAN AMERICAN for No Finding is: 0.09110169491525423
# =======================================================================================================
# 7 -- 147
# False Positive Rate in F/HISPANIC/LATINO for No Finding is: 0.047619047619047616
# =======================================================================================================
# 89 -- 973
# False Positive Rate in F/OTHER for No Finding is: 0.09146968139773895
# =======================================================================================================
# 51 -- 679
# False Positive Rate in F/ASIAN for No Finding is: 0.07511045655375552
# =======================================================================================================
# 18 -- 117
# False Positive Rate in F/AMERICAN INDIAN/ALASKA NATIVE for No Finding is: 0.15384615384615385
# =======================================================================================================
# ==================================== Calculating FP in vector embedded CXP====================================
# 199 -- 3836
# False Positive Rate in M/60-80 for No Finding is: 0.051876955161626694
# =======================================================================================================
# 197 -- 2820
# False Positive Rate in M/40-60 for No Finding is: 0.0698581560283688
# =======================================================================================================
# 106 -- 1081
# False Positive Rate in M/20-40 for No Finding is: 0.09805735430157261
# =======================================================================================================
# 93 -- 1766
# False Positive Rate in M/80+ for No Finding is: 0.05266138165345413
# =======================================================================================================
# 4 -- 76
# False Positive Rate in M/0-20 for No Finding is: 0.05263157894736842
# =======================================================================================================
# 204 -- 2690
# False Positive Rate in F/60-80 for No Finding is: 0.0758364312267658
# =======================================================================================================
# 146 -- 1950
# False Positive Rate in F/40-60 for No Finding is: 0.07487179487179488
# =======================================================================================================
# 49 -- 716
# False Positive Rate in F/20-40 for No Finding is: 0.06843575418994413
# =======================================================================================================
# 132 -- 1267
# False Positive Rate in F/80+ for No Finding is: 0.10418310970797158
# =======================================================================================================
# 4 -- 49
# False Positive Rate in F/0-20 for No Finding is: 0.08163265306122448
# =======================================================================================================
# ==================================== Calculating FP in vector embedded CXP====================================
# 244 -- 4500
# False Positive Rate in WHITE/60-80 for No Finding is: 0.05422222222222222
# =======================================================================================================
# 199 -- 2819
# False Positive Rate in WHITE/40-60 for No Finding is: 0.07059240865555161
# =======================================================================================================
# 90 -- 979
# False Positive Rate in WHITE/20-40 for No Finding is: 0.09193054136874361
# =======================================================================================================
# 163 -- 2255
# False Positive Rate in WHITE/80+ for No Finding is: 0.07228381374722838
# =======================================================================================================
# 1 -- 68
# False Positive Rate in WHITE/0-20 for No Finding is: 0.014705882352941176
# =======================================================================================================
# 21 -- 297
# False Positive Rate in BLACK/AFRICAN AMERICAN/60-80 for No Finding is: 0.0707070707070707
# =======================================================================================================
# 39 -- 337
# False Positive Rate in BLACK/AFRICAN AMERICAN/40-60 for No Finding is: 0.11572700296735905
# =======================================================================================================
# 11 -- 128
# False Positive Rate in BLACK/AFRICAN AMERICAN/20-40 for No Finding is: 0.0859375
# =======================================================================================================
# 14 -- 147
# False Positive Rate in BLACK/AFRICAN AMERICAN/80+ for No Finding is: 0.09523809523809523
# =======================================================================================================
# 0 -- 29
# False Positive Rate in BLACK/AFRICAN AMERICAN/0-20 for No Finding is: 0.0
# =======================================================================================================
# 3 -- 114
# False Positive Rate in HISPANIC/LATINO/60-80 for No Finding is: 0.02631578947368421
# =======================================================================================================
# 8 -- 141
# False Positive Rate in HISPANIC/LATINO/40-60 for No Finding is: 0.05673758865248227
# =======================================================================================================
# 2 -- 105
# False Positive Rate in HISPANIC/LATINO/20-40 for No Finding is: 0.01904761904761905
# =======================================================================================================
# 3 -- 43
# False Positive Rate in HISPANIC/LATINO/80+ for No Finding is: 0.06976744186046512
# =======================================================================================================
# 1 -- 3
# False Positive Rate in HISPANIC/LATINO/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# 62 -- 731
# False Positive Rate in OTHER/60-80 for No Finding is: 0.08481532147742818
# =======================================================================================================
# 54 -- 918
# False Positive Rate in OTHER/40-60 for No Finding is: 0.058823529411764705
# =======================================================================================================
# 32 -- 336
# False Positive Rate in OTHER/20-40 for No Finding is: 0.09523809523809523
# =======================================================================================================
# 25 -- 212
# False Positive Rate in OTHER/80+ for No Finding is: 0.1179245283018868
# =======================================================================================================
# 4 -- 12
# False Positive Rate in OTHER/0-20 for No Finding is: 0.3333333333333333
# =======================================================================================================
# 62 -- 798
# False Positive Rate in ASIAN/60-80 for No Finding is: 0.07769423558897243
# =======================================================================================================
# 37 -- 503
# False Positive Rate in ASIAN/40-60 for No Finding is: 0.073558648111332
# =======================================================================================================
# 12 -- 187
# False Positive Rate in ASIAN/20-40 for No Finding is: 0.06417112299465241
# =======================================================================================================
# 19 -- 365
# False Positive Rate in ASIAN/80+ for No Finding is: 0.052054794520547946
# =======================================================================================================
# 0 -- 10
# False Positive Rate in ASIAN/0-20 for No Finding is: 0.0
# =======================================================================================================
# 11 -- 86
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/60-80 for No Finding is: 0.12790697674418605
# =======================================================================================================
# 6 -- 52
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/40-60 for No Finding is: 0.11538461538461539
# =======================================================================================================
# 8 -- 62
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/20-40 for No Finding is: 0.12903225806451613
# =======================================================================================================
# 1 -- 11
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/80+ for No Finding is: 0.09090909090909091
# =======================================================================================================
# 2 -- 3
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/0-20 for No Finding is: 0.6666666666666666
# =======================================================================================================
# ==================================== Calculating FP in vector embedded mimic cxr====================================
# 128 -- 2686
# False Positive Rate in WHITE/M and 60-80 for No Finding is: 0.04765450483991065
# [0.048]
# 9 -- 153
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 60-80 for No Finding is: 0.058823529411764705
# [0.048, 0.059]
# 1 -- 59
# False Positive Rate in HISPANIC/LATINO/M and 60-80 for No Finding is: 0.01694915254237288
# [0.048, 0.059, 0.017]
# 22 -- 395
# False Positive Rate in OTHER/M and 60-80 for No Finding is: 0.05569620253164557
# [0.048, 0.059, 0.017, 0.056]
# 37 -- 521
# False Positive Rate in ASIAN/M and 60-80 for No Finding is: 0.0710172744721689
# [0.048, 0.059, 0.017, 0.056, 0.071]
# 2 -- 22
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 60-80 for No Finding is: 0.09090909090909091
# [0.048, 0.059, 0.017, 0.056, 0.071, 0.091]
# 114 -- 1687
# False Positive Rate in WHITE/M and 40-60 for No Finding is: 0.06757557794902193
# [0.068]
# 20 -- 188
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 40-60 for No Finding is: 0.10638297872340426
# [0.068, 0.106]
# 4 -- 72
# False Positive Rate in HISPANIC/LATINO/M and 40-60 for No Finding is: 0.05555555555555555
# [0.068, 0.106, 0.056]
# 32 -- 499
# False Positive Rate in OTHER/M and 40-60 for No Finding is: 0.06412825651302605
# [0.068, 0.106, 0.056, 0.064]
# 24 -- 346
# False Positive Rate in ASIAN/M and 40-60 for No Finding is: 0.06936416184971098
# [0.068, 0.106, 0.056, 0.064, 0.069]
# 3 -- 28
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 40-60 for No Finding is: 0.10714285714285714
# [0.068, 0.106, 0.056, 0.064, 0.069, 0.107]
# 65 -- 592
# False Positive Rate in WHITE/M and 20-40 for No Finding is: 0.1097972972972973
# [0.11]
# 7 -- 54
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 20-40 for No Finding is: 0.12962962962962962
# [0.11, 0.13]
# 2 -- 91
# False Positive Rate in HISPANIC/LATINO/M and 20-40 for No Finding is: 0.02197802197802198
# [0.11, 0.13, 0.022]
# 22 -- 210
# False Positive Rate in OTHER/M and 20-40 for No Finding is: 0.10476190476190476
# [0.11, 0.13, 0.022, 0.105]
# 6 -- 93
# False Positive Rate in ASIAN/M and 20-40 for No Finding is: 0.06451612903225806
# [0.11, 0.13, 0.022, 0.105, 0.065]
# 4 -- 41
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 20-40 for No Finding is: 0.0975609756097561
# [0.11, 0.13, 0.022, 0.105, 0.065, 0.098]
# 62 -- 1342
# False Positive Rate in WHITE/M and 80+ for No Finding is: 0.046199701937406856
# [0.046]
# 6 -- 46
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 80+ for No Finding is: 0.13043478260869565
# [0.046, 0.13]
# 2 -- 35
# False Positive Rate in HISPANIC/LATINO/M and 80+ for No Finding is: 0.05714285714285714
# [0.046, 0.13, 0.057]
# 11 -- 124
# False Positive Rate in OTHER/M and 80+ for No Finding is: 0.08870967741935484
# [0.046, 0.13, 0.057, 0.089]
# 12 -- 214
# False Positive Rate in ASIAN/M and 80+ for No Finding is: 0.056074766355140186
# [0.046, 0.13, 0.057, 0.089, 0.056]
# 0 -- 5
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 80+ for No Finding is: 0.0
# [0.046, 0.13, 0.057, 0.089, 0.056, 0.0]
# 1 -- 30
# False Positive Rate in WHITE/M and 0-20 for No Finding is: 0.03333333333333333
# [0.033]
# 0 -- 25
# False Positive Rate in BLACK/AFRICAN AMERICAN/M and 0-20 for No Finding is: 0.0
# [0.033, 0.0]
# 1 -- 2
# False Positive Rate in HISPANIC/LATINO/M and 0-20 for No Finding is: 0.5
# [0.033, 0.0, 0.5]
# 1 -- 8
# False Positive Rate in OTHER/M and 0-20 for No Finding is: 0.125
# [0.033, 0.0, 0.5, 0.125]
# 0 -- 10
# False Positive Rate in ASIAN/M and 0-20 for No Finding is: 0.0
# [0.033, 0.0, 0.5, 0.125, 0.0]
# 1 -- 1
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/M and 0-20 for No Finding is: 1.0
# [0.033, 0.0, 0.5, 0.125, 0.0, 1.0]
# 116 -- 1814
# False Positive Rate in WHITE/F and 60-80 for No Finding is: 0.0639470782800441
# [0.064]
# 12 -- 144
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 60-80 for No Finding is: 0.08333333333333333
# [0.064, 0.083]
# 2 -- 55
# False Positive Rate in HISPANIC/LATINO/F and 60-80 for No Finding is: 0.03636363636363636
# [0.064, 0.083, 0.036]
# 40 -- 336
# False Positive Rate in OTHER/F and 60-80 for No Finding is: 0.11904761904761904
# [0.064, 0.083, 0.036, 0.119]
# 25 -- 277
# False Positive Rate in ASIAN/F and 60-80 for No Finding is: 0.09025270758122744
# [0.064, 0.083, 0.036, 0.119, 0.09]
# 9 -- 64
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 60-80 for No Finding is: 0.140625
# [0.064, 0.083, 0.036, 0.119, 0.09, 0.141]
# 85 -- 1132
# False Positive Rate in WHITE/F and 40-60 for No Finding is: 0.07508833922261485
# [0.075]
# 19 -- 149
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 40-60 for No Finding is: 0.12751677852348994
# [0.075, 0.128]
# 4 -- 69
# False Positive Rate in HISPANIC/LATINO/F and 40-60 for No Finding is: 0.057971014492753624
# [0.075, 0.128, 0.058]
# 22 -- 419
# False Positive Rate in OTHER/F and 40-60 for No Finding is: 0.05250596658711217
# [0.075, 0.128, 0.058, 0.053]
# 13 -- 157
# False Positive Rate in ASIAN/F and 40-60 for No Finding is: 0.08280254777070063
# [0.075, 0.128, 0.058, 0.053, 0.083]
# 3 -- 24
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 40-60 for No Finding is: 0.125
# [0.075, 0.128, 0.058, 0.053, 0.083, 0.125]
# 25 -- 387
# False Positive Rate in WHITE/F and 20-40 for No Finding is: 0.06459948320413436
# [0.065]
# 4 -- 74
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 20-40 for No Finding is: 0.05405405405405406
# [0.065, 0.054]
# 0 -- 14
# False Positive Rate in HISPANIC/LATINO/F and 20-40 for No Finding is: 0.0
# [0.065, 0.054, 0.0]
# 10 -- 126
# False Positive Rate in OTHER/F and 20-40 for No Finding is: 0.07936507936507936
# [0.065, 0.054, 0.0, 0.079]
# 6 -- 94
# False Positive Rate in ASIAN/F and 20-40 for No Finding is: 0.06382978723404255
# [0.065, 0.054, 0.0, 0.079, 0.064]
# 4 -- 21
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 20-40 for No Finding is: 0.19047619047619047
# [0.065, 0.054, 0.0, 0.079, 0.064, 0.19]
# 101 -- 913
# False Positive Rate in WHITE/F and 80+ for No Finding is: 0.11062431544359255
# [0.111]
# 8 -- 101
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 80+ for No Finding is: 0.07920792079207921
# [0.111, 0.079]
# 1 -- 8
# False Positive Rate in HISPANIC/LATINO/F and 80+ for No Finding is: 0.125
# [0.111, 0.079, 0.125]
# 14 -- 88
# False Positive Rate in OTHER/F and 80+ for No Finding is: 0.1590909090909091
# [0.111, 0.079, 0.125, 0.159]
# 7 -- 151
# False Positive Rate in ASIAN/F and 80+ for No Finding is: 0.046357615894039736
# [0.111, 0.079, 0.125, 0.159, 0.046]
# 1 -- 6
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 80+ for No Finding is: 0.16666666666666666
# [0.111, 0.079, 0.125, 0.159, 0.046, 0.167]
# 0 -- 38
# False Positive Rate in WHITE/F and 0-20 for No Finding is: 0.0
# [0.0]
# 0 -- 4
# False Positive Rate in BLACK/AFRICAN AMERICAN/F and 0-20 for No Finding is: 0.0
# [0.0, 0.0]
# 0 -- 1
# False Positive Rate in HISPANIC/LATINO/F and 0-20 for No Finding is: 0.0
# [0.0, 0.0, 0.0]
# 3 -- 4
# False Positive Rate in OTHER/F and 0-20 for No Finding is: 0.75
# [0.0, 0.0, 0.0, 0.75]
# =======================================================================================================
# [0.0, 0.0, 0.0, 0.75, nan]
# 1 -- 2
# False Positive Rate in AMERICAN INDIAN/ALASKA NATIVE/F and 0-20 for No Finding is: 0.5
# [0.0, 0.0, 0.0, 0.75, nan, 0.5]
# Seed :  77
